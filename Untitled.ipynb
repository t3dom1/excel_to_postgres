# %%
/home/jovyan/data'
# Out:
# '/home/jovyan/data'

# %%
ls
# Out:
# Book.xlsx  logger_setup.py  __pycache__/    Untitled.ipynb
# db.py      main.ipynb       saver.py        validator.py
# loader.py  output_data.csv  transformer.py  yaml_file.yml

# %%
# Out:
#   Cell In[3], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
